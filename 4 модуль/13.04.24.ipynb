# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # Задача 1

# %%
print(np.float32(42))
print(np.array([12, 23, 67]))
print(np.array([[2, 92, 12], [13, 45, 53], [17, 7, 11]]))
print(np.array([[[2, 92, 12], [13, 45, 53], [17, 7, 11]],
								[[2, 92, 12], [13, 45, 53], [17, 7, 11]]]))
# Out:
# 42.0
# 12 23 67
# [ 2 92 12] [13 45 53] [17  7 11]
# [[ 2 92 12]
#  [13 45 53]
#  [17  7 11]] [[ 2 92 12]
#  [13 45 53]
#  [17  7 11]]

# %% [markdown]
# # Задача 2

# %%
df = pd.read_csv("./car_data.csv")

df.describe()
# Out:
#               Year  Selling_Price  Present_Price     Kms_Driven       Owner
# count   301.000000     301.000000     301.000000     301.000000  301.000000
# mean   2013.627907       4.661296       7.628472   36947.205980    0.043189
# std       2.891554       5.082812       8.644115   38886.883882    0.247915
# min    2003.000000       0.100000       0.320000     500.000000    0.000000
# 25%    2012.000000       0.900000       1.200000   15000.000000    0.000000
# 50%    2014.000000       3.600000       6.400000   32000.000000    0.000000
# 75%    2016.000000       6.000000       9.900000   48767.000000    0.000000
# max    2018.000000      35.000000      92.600000  500000.000000    3.000000

# %%
df.sample(10)
# Out:
#              Car_Name  Year  Selling_Price  Present_Price  Kms_Driven  \
# 197  Honda CB twister  2010           0.16           0.51       33000
# 171  Hero Passion Pro  2015           0.40           0.55        6700
# 234         grand i10  2015           5.50           5.70        4492
# 215             verna  2012           4.50           9.40       36100
# 282              city  2014           8.25          14.00       63000
# 251              city  2013           5.00           9.90       56701
# 205         grand i10  2016           5.25           5.70        3493
# 212             creta  2016          11.25          13.60       22671
# 33             ertiga  2014           6.00           9.95       45000
# 261              brio  2016           5.50           5.97        5600
#
#     Fuel_Type Seller_Type Transmission  Owner
# 197    Petrol  Individual       Manual      0
# 171    Petrol  Individual       Manual      0
# 234    Petrol      Dealer       Manual      0
# ...

# %% [markdown]
# # Задание 3
# распределение не относится к нормальному

# %%
sns.displot(df, x="Present_Price", kde=True)

# %% [markdown]
# # Задача 4

# %%
mean = np.float32(df['Present_Price'].mean())
print(mean)
# Out:
# 7.628472

# %%
cheap = df[df['Present_Price'] <= mean]
cheap.describe()
# Out:
#               Year  Selling_Price  Present_Price     Kms_Driven       Owner
# count   183.000000     183.000000     183.000000     183.000000  183.000000
# mean   2013.633880       2.052295       3.142678   31635.830601    0.054645
# std       2.793704       1.805878       2.568933   42669.593796    0.227909
# min    2003.000000       0.100000       0.320000     500.000000    0.000000
# 25%    2012.000000       0.480000       0.815000   12239.500000    0.000000
# 50%    2014.000000       1.150000       1.750000   24678.000000    0.000000
# 75%    2016.000000       3.475000       5.705000   41267.000000    0.000000
# max    2017.000000       6.250000       7.600000  500000.000000    1.000000

# %%
expensive = df[df['Present_Price'] > mean]
expensive.describe()
# Out:
#               Year  Selling_Price  Present_Price     Kms_Driven       Owner
# count   118.000000     118.000000     118.000000     118.000000  118.000000
# mean   2013.618644       8.707458      14.585254   45184.338983    0.025424
# std       3.049224       5.832027      10.051963   30539.545410    0.276172
# min    2003.000000       1.500000       7.700000    2071.000000    0.000000
# 25%    2012.000000       5.212500       9.400000   24593.000000    0.000000
# 50%    2015.000000       7.225000      11.300000   41221.000000    0.000000
# 75%    2016.000000       9.612500      14.865000   58810.500000    0.000000
# max    2018.000000      35.000000      92.600000  197176.000000    3.000000
